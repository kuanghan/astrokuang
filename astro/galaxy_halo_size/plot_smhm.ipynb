# %% [markdown]
# ## Plot stellar mass-halo mass (SMHM) relations used in this paper

# %%
import pickle
import numpy as np
import smass_hmass as smhm
import mass_stellar2halo as msh
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Our own SMHM relation

# %%
smhm_candels = pickle.load(open('smhm_candels.p'))
fig1 = smhm.plot_smhm_candels(smhm_candels)
# fig1.savefig('ms/SMHM_1.pdf')

# %% [markdown]
# ### Compare galaxy type-dependent SMHM relations in the literature

# %%
fig2 = smhm.plot_smhm_gtypes()
# fig2.savefig('ms/SMHM_gtypes.pdf')

# %% [markdown]
# ### Plot all four SMHM relations used in this paper

# %%
ax3, fig3 = smhm.plot_smhm()
# fig3.savefig('ms/SMHM_all.pdf')
# Out:
# Converting for 0.2 < z < 0.5
# The number density ratio is X = 9.66e-01
# The stellar mass ratio is Y = 1.02e+00
# Converting for 0.5 < z < 0.8
# The number density ratio is X = 9.33e-01
# The stellar mass ratio is Y = 1.03e+00
# Converting for 0.8 < z < 1.0
# The number density ratio is X = 8.96e-01
# The stellar mass ratio is Y = 1.03e+00
# Converting for 1.0 < z < 1.2
# The number density ratio is X = 8.53e-01
# The stellar mass ratio is Y = 1.04e+00
# Converting for 1.2 < z < 1.5
# The number density ratio is X = 8.06e-01
# The stellar mass ratio is Y = 1.05e+00
# Converting for 1.5 < z < 2.0
# The number density ratio is X = 8.28e-01
# The stellar mass ratio is Y = 1.05e+00
# Converting for 2.0 < z < 2.5
# The number density ratio is X = 7.66e-01
# The stellar mass ratio is Y = 1.06e+00
# Converting for 2.5 < z < 3.0
# The number density ratio is X = 7.03e-01
# The stellar mass ratio is Y = 1.06e+00
# Working on 0 < z < 0.5:
# ...
