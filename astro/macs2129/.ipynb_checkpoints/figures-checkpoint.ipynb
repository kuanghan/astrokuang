# %%
import plot_sedfit
import montage_fig1
# %matplotlib inline
# Out:
# /Users/khuang/anaconda/envs/py27/lib/python2.7/site-packages/pysynphot/refs.py:121: UserWarning: No thermal tables found, no thermal calculations can be performed. No files found for /Users/khuang/lib/pysyn_cdbs/mtab/*_tmt.fits.
#   'no thermal calculations can be performed. ' + str(e))

# %% [markdown]
# ### Make a plot of the spectral energy distribution fits

# %%
axes = plot_sedfit.plot_sedfit_all()
# Out:
# ------------------------------------------------------------
# Best-fit parameters at z=6.87:
# For mu = 1.00:
# Stellar mass = 1.90e+08 [M_solar]
# Age = 1.05e+07 [yrs]
# SFR = 19.11 [M_solar/yr]
# tau = 1.00 [Gyr]
# E(B-V) = 0.00
# Total chi-square = 9.36
# Best-fit template name:
# bc2003_lr_m42_chab_csf_age7.0200_dust0.00.sed
# ------------------------------------------------------------
# /Users/khuang/anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/cbook.py:2644: UserWarning: Saw kwargs [u'c', u'color'] which are all aliases for u'color'.  Kept value from u'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# ------------------------------------------------------------
# Best-fit parameters at z=1.57:
# For mu = 1.00:
# Stellar mass = 5.22e+08 [M_solar]
# Age = 5.71e+08 [yrs]
# SFR = 1.33 [M_solar/yr]
# tau = 1.00 [Gyr]
# E(B-V) = 0.30
# Total chi-square = 9.66
# Best-fit template name:
# bc2003_lr_m62_chab_csf_age8.7565_dust0.30.sed
# ...

# %%
### Make a plot showing the Hubble image of each of the three multiple images

# %%
fig1 = montage_fig1.montageAll()
# Out:
# (i, j) = (0, 0)
# *************************************
# Making montage for Image A...
# *************************************
# INFO
# /Users/khuang/anaconda/envs/py27/lib/python2.7/site-packages/aplpy/labels.py:432: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self.coord == x or self.axis.apl_tick_positions_world[ipos] > 0:
# :
#                 Inconsistent SIP distortion information is present in header:
#                 SIP coefficients were detected, but CTYPE is missing "-SIP" suffix,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If image is already distortion-corrected (eg, drizzled) then
#                 distortion components should not apply. For such distortion-corrected
#                 images, please use ``wcs_pix2world`` or ``wcs_world2pix`` instead.
#
# ...

# %%
fig1
